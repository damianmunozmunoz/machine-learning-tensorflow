# %% [markdown]
# El **transfer learning** consiste en emplear las capas de convolución de un modelo ya entrenado sobre una basta cantidad de imágenes y sólamente entrenar las capas de la red neuronal.
# A esto se le llama fine tuning
# Algunas CNN preentrenadas que podemos emplear son:
# | Modelo | Tamaño de entrada | Salida | Dataset entrenado | Tamaño del dataset |
# |:-------|:-----------------:|:------:|:-----------------:|-------------------:|
# | VGG16 | (224,224,3) | 1000 | 'imagenet' | 1281167 |
# | ResNet50 | (224,224,3) | 1000 | 'imagenet' | 1281167 |
# | MobileNetV2 | (224,224,3) | 1000 | 'imagenet' | 1281167 |
# | EfficientNetB7 | (600,600,3) | 1000 | 'imagenet' | 1281167 |
#
# Nosotros vamos a usar en este caso un dataset que es Covid19 Image Dataset que clasifica entre covid-19, neumonía y normal.
# En su información podemos ver que solo tiene 317 imágenes.
# Por eso mismo, vamos a tratar con estas pocas imágenes de conseguir una efectividad decente.

# %%
# !pip install -q tensorflow==2.15.0 keras==2.15.0 tensorflow_hub==0.15.0

# %%
paths = ["/kaggle/input/covid19-image-dataset/Covid19-dataset/train/",
        "/kaggle/input/covid19-image-dataset/Covid19-dataset/test/"]

# %%
import os, glob, cv2, numpy as np, matplotlib.pyplot as plt

# %%
def imshow(img):
    fig, ax = plt.subplots(1, 1, figsize = (8,8))
    ax = imshow(img, cmap = 'gray')

# %%
possible_labels = os.listdir(paths[0])

# %%
possible_labels
# Out:
# ['Normal', 'Viral Pneumonia', 'Covid']

# %%
data = []

for i, path in enumerate(paths):
    for label_int, label_string in enumerate(possible_labels):
        filenames = glob.glob(path + label_string + "/*.jpg") + glob.glob(path + label_string + "/*.jpeg") + glob.glob(path + label_string + "/*.png")
        for filename in filenames:
            img = cv2.imread(filename)
            data.append([label_int, cv2.resize(img, (224, 224))])
len(data)
# Out:
# 317

# %%
import random
random.Random(0).shuffle(data)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for i, sample in enumerate(data):
    label = sample[0]
    img = sample[1]
    if i <= 0.8 * len(data):
        x_train.append(img)
        y_train.append(label)
    elif i > 0.8 * len(data) and i <= 0.9 * len(data):
        x_val.append(img)
        y_val.append(label)
    else:
        x_test.append(img)
        y_test.append(label)

x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
import tensorflow as tf
y_trainOneHot = tf.one_hot(y_train, len(possible_labels))
y_valOneHot = tf.one_hot(y_val, len(possible_labels))
y_testOneHot = tf.one_hot(y_test, len(possible_labels))
# Out:
# 2025-10-07 21:30:01.700398: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-07 21:30:01.700452: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-07 21:30:01.702064: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense

# %%
def cnn_model():
    model = Sequential()
    model.add(Convolution2D(32, (3,3), input_shape = (224,224,3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Flatten())
    model.add(Dense(30, activation = 'relu'))
    model.add(Dense(3, activation = 'softmax'))
    model.compile(optimizer = 'SGD', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = cnn_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  flatten (Flatten)           (None, 394272)            0
#
#  dense (Dense)               (None, 30)                11828190
#
#  dense_1 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 11829179 (45.12 MB)
# Trainable params: 11829179 (45.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
checkpoint = ModelCheckpoint('checkpoint/model.{epoch:d}.h5', save_best_only = False, save_freq = 'epoch')
tensorboard_callback = tf.keras.callbacks.TensorBoard('logs/cnn_logs', histogram_freq = 1)

# %%
model.fit(x_train,
         y_trainOneHot,
         epochs = 40,
         batch_size = 100,
         validation_data = (x_val, y_valOneHot)
         )
# Out:
# Epoch 1/40
# 3/3 [==============================] - 5s 1s/step - loss: 8446007.0000 - accuracy: 0.4016 - val_loss: 1385.9751 - val_accuracy: 0.3438
# Epoch 2/40
# 3/3 [==============================] - 4s 1s/step - loss: 38931320.0000 - accuracy: 0.3898 - val_loss: 335.2518 - val_accuracy: 0.3750
# Epoch 3/40
# 3/3 [==============================] - 4s 1s/step - loss: 158.6428 - accuracy: 0.3504 - val_loss: 1.0985 - val_accuracy: 0.3750
# Epoch 4/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0969 - accuracy: 0.4291 - val_loss: 1.0984 - val_accuracy: 0.3750
# Epoch 5/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0965 - accuracy: 0.4291 - val_loss: 1.0983 - val_accuracy: 0.3750
# Epoch 6/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0962 - accuracy: 0.4291 - val_loss: 1.0981 - val_accuracy: 0.3750
# Epoch 7/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0958 - accuracy: 0.4291 - val_loss: 1.0980 - val_accuracy: 0.3750
# Epoch 8/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0955 - accuracy: 0.4291 - val_loss: 1.0978 - val_accuracy: 0.3750
# Epoch 9/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0951 - accuracy: 0.4291 - val_loss: 1.0977 - val_accuracy: 0.3750
# Epoch 10/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0948 - accuracy: 0.4291 - val_loss: 1.0975 - val_accuracy: 0.3750
# Epoch 11/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0945 - accuracy: 0.4291 - val_loss: 1.0975 - val_accuracy: 0.3750
# Epoch 12/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0942 - accuracy: 0.4291 - val_loss: 1.0974 - val_accuracy: 0.3750
# Epoch 13/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0938 - accuracy: 0.4291 - val_loss: 1.0973 - val_accuracy: 0.3750
# Epoch 14/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0935 - accuracy: 0.4291 - val_loss: 1.0971 - val_accuracy: 0.3750
# Epoch 15/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0931 - accuracy: 0.4291 - val_loss: 1.0971 - val_accuracy: 0.3750
# Epoch 16/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0928 - accuracy: 0.4291 - val_loss: 1.0970 - val_accuracy: 0.3750
# Epoch 17/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0925 - accuracy: 0.4291 - val_loss: 1.0970 - val_accuracy: 0.3750
# Epoch 18/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0923 - accuracy: 0.4291 - val_loss: 1.0969 - val_accuracy: 0.3750
# Epoch 19/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0919 - accuracy: 0.4291 - val_loss: 1.0968 - val_accuracy: 0.3750
# Epoch 20/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0917 - accuracy: 0.4291 - val_loss: 1.0967 - val_accuracy: 0.3750
# Epoch 21/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0914 - accuracy: 0.4291 - val_loss: 1.0967 - val_accuracy: 0.3750
# Epoch 22/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0911 - accuracy: 0.4291 - val_loss: 1.0966 - val_accuracy: 0.3750
# Epoch 23/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0908 - accuracy: 0.4291 - val_loss: 1.0965 - val_accuracy: 0.3750
# Epoch 24/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0905 - accuracy: 0.4291 - val_loss: 1.0965 - val_accuracy: 0.3750
# Epoch 25/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0903 - accuracy: 0.4291 - val_loss: 1.0964 - val_accuracy: 0.3750
# Epoch 26/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0901 - accuracy: 0.4291 - val_loss: 1.0964 - val_accuracy: 0.3750
# Epoch 27/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0898 - accuracy: 0.4291 - val_loss: 1.0963 - val_accuracy: 0.3750
# Epoch 28/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0896 - accuracy: 0.4291 - val_loss: 1.0962 - val_accuracy: 0.3750
# Epoch 29/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0894 - accuracy: 0.4291 - val_loss: 1.0962 - val_accuracy: 0.3750
# Epoch 30/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0891 - accuracy: 0.4291 - val_loss: 1.0962 - val_accuracy: 0.3750
# Epoch 31/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0890 - accuracy: 0.4291 - val_loss: 1.0961 - val_accuracy: 0.3750
# Epoch 32/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0887 - accuracy: 0.4291 - val_loss: 1.0961 - val_accuracy: 0.3750
# Epoch 33/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0885 - accuracy: 0.4291 - val_loss: 1.0961 - val_accuracy: 0.3750
# Epoch 34/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0883 - accuracy: 0.4291 - val_loss: 1.0961 - val_accuracy: 0.3750
# Epoch 35/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0881 - accuracy: 0.4291 - val_loss: 1.0961 - val_accuracy: 0.3750
# Epoch 36/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0879 - accuracy: 0.4291 - val_loss: 1.0960 - val_accuracy: 0.3750
# Epoch 37/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0877 - accuracy: 0.4291 - val_loss: 1.0960 - val_accuracy: 0.3750
# Epoch 38/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0875 - accuracy: 0.4291 - val_loss: 1.0959 - val_accuracy: 0.3750
# Epoch 39/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0873 - accuracy: 0.4291 - val_loss: 1.0959 - val_accuracy: 0.3750
# Epoch 40/40
# 3/3 [==============================] - 4s 1s/step - loss: 1.0871 - accuracy: 0.4291 - val_loss: 1.0959 - val_accuracy: 0.3750

# %%
possible_labels[np.argmax(model.predict(x_test[0:1]))]
# Out:
# 1/1 [==============================] - 0s 83ms/step
# 'Covid'

# %%
model.evaluate(x = x_test, y = y_testOneHot)
# Out:
# 1/1 [==============================] - 0s 205ms/step - loss: 1.0741 - accuracy: 0.5161
# [1.0741198062896729, 0.5161290168762207]

# %% [markdown]
# # **Método con transfer learning**
# ---

# %%
# !pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.11/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow_hub) (3.20.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.12.0->tensorflow_hub) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.12.0->tensorflow_hub) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.12.0->tensorflow_hub) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.12.0->tensorflow_hub) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.12.0->tensorflow_hub) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.12.0->tensorflow_hub) (2024.2.0)

# %%
import tensorflow_hub as hub

# %%
#Copiamos la url del modelo ya entrenado que vamos a usar
path_model = 'https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/5'

# %%
#Definimos nuestro modelo de transfer learning
def tfLearning_model():
    model = tf.keras.Sequential()
    #Ya no hacemos convoluciones ni flatten porque eso lo ha hecho ya el otro modelo
    #Aquí solo añadiremos ese modelo y le ponemos que no se entrene porque ya está entrenado
    model.add(hub.KerasLayer(path_model, trainable = False, input_shape = (224, 224, 3)))
    model.add(tf.keras.layers.Dense(30, activation = 'relu'))
    model.add(tf.keras.layers.Dense(3, activation = 'softmax'))
    model.compile(optimizer = 'SGD', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
model_tfLearning = tfLearning_model()

# %%
#Este resumen nos dice que entrenemos con pocas imágenes
model_tfLearning.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_1 (KerasLayer)  (None, 1280)              2257984
#
#  dense_4 (Dense)             (None, 30)                38430
#
#  dense_5 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 2296507 (8.76 MB)
# Trainable params: 38523 (150.48 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model_tfLearning.fit(x_train,
         y_trainOneHot,
         epochs = 40,
         batch_size = 100,
         validation_data = (x_val, y_valOneHot)
         )
# Out:
# Epoch 1/40
# 3/3 [==============================] - 12s 2s/step - loss: 1.2156 - accuracy: 0.3346 - val_loss: 1.1812 - val_accuracy: 0.3750
# Epoch 2/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.9902 - accuracy: 0.5354 - val_loss: 0.8576 - val_accuracy: 0.6250
# Epoch 3/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.8940 - accuracy: 0.6220 - val_loss: 0.8844 - val_accuracy: 0.5938
# Epoch 4/40
# 3/3 [==============================] - 5s 2s/step - loss: 1.0170 - accuracy: 0.4685 - val_loss: 1.0872 - val_accuracy: 0.3750
# Epoch 5/40
# 3/3 [==============================] - 5s 2s/step - loss: 1.0361 - accuracy: 0.4370 - val_loss: 0.7770 - val_accuracy: 0.6250
# Epoch 6/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.8471 - accuracy: 0.5906 - val_loss: 0.7751 - val_accuracy: 0.6875
# Epoch 7/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.8452 - accuracy: 0.6181 - val_loss: 0.7746 - val_accuracy: 0.7188
# Epoch 8/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.8079 - accuracy: 0.6378 - val_loss: 0.6997 - val_accuracy: 0.7188
# Epoch 9/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.7313 - accuracy: 0.7008 - val_loss: 0.6458 - val_accuracy: 0.7500
# Epoch 10/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.7186 - accuracy: 0.7283 - val_loss: 0.8595 - val_accuracy: 0.5938
# Epoch 11/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.8119 - accuracy: 0.6220 - val_loss: 0.6876 - val_accuracy: 0.7812
# Epoch 12/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.7507 - accuracy: 0.6929 - val_loss: 0.7026 - val_accuracy: 0.6875
# Epoch 13/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.7300 - accuracy: 0.7205 - val_loss: 0.6141 - val_accuracy: 0.6875
# Epoch 14/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.5977 - accuracy: 0.7835 - val_loss: 0.5579 - val_accuracy: 0.7188
# Epoch 15/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.5768 - accuracy: 0.8150 - val_loss: 0.5503 - val_accuracy: 0.8125
# Epoch 16/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.5904 - accuracy: 0.7874 - val_loss: 0.5890 - val_accuracy: 0.7188
# Epoch 17/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.5643 - accuracy: 0.8150 - val_loss: 0.5310 - val_accuracy: 0.7188
# Epoch 18/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.5475 - accuracy: 0.8031 - val_loss: 0.5111 - val_accuracy: 0.8438
# Epoch 19/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.5937 - accuracy: 0.7874 - val_loss: 0.5540 - val_accuracy: 0.7188
# Epoch 20/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.5580 - accuracy: 0.8228 - val_loss: 0.4812 - val_accuracy: 0.8438
# Epoch 21/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.5061 - accuracy: 0.8425 - val_loss: 0.4726 - val_accuracy: 0.8438
# Epoch 22/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.5046 - accuracy: 0.8425 - val_loss: 0.4613 - val_accuracy: 0.8438
# Epoch 23/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4843 - accuracy: 0.8543 - val_loss: 0.4781 - val_accuracy: 0.8438
# Epoch 24/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.4819 - accuracy: 0.8622 - val_loss: 0.4506 - val_accuracy: 0.8438
# Epoch 25/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4664 - accuracy: 0.8819 - val_loss: 0.4517 - val_accuracy: 0.8438
# Epoch 26/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4582 - accuracy: 0.8622 - val_loss: 0.4444 - val_accuracy: 0.8750
# Epoch 27/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.4528 - accuracy: 0.8740 - val_loss: 0.4422 - val_accuracy: 0.8750
# Epoch 28/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4500 - accuracy: 0.8661 - val_loss: 0.4317 - val_accuracy: 0.8750
# Epoch 29/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4431 - accuracy: 0.8622 - val_loss: 0.4712 - val_accuracy: 0.8438
# Epoch 30/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4425 - accuracy: 0.8504 - val_loss: 0.4063 - val_accuracy: 0.8750
# Epoch 31/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4356 - accuracy: 0.8661 - val_loss: 0.4017 - val_accuracy: 0.8750
# Epoch 32/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4236 - accuracy: 0.8819 - val_loss: 0.4452 - val_accuracy: 0.8125
# Epoch 33/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4107 - accuracy: 0.8898 - val_loss: 0.4053 - val_accuracy: 0.9062
# Epoch 34/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.4018 - accuracy: 0.8976 - val_loss: 0.3968 - val_accuracy: 0.8750
# Epoch 35/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.3954 - accuracy: 0.9055 - val_loss: 0.4222 - val_accuracy: 0.8125
# Epoch 36/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.4178 - accuracy: 0.8701 - val_loss: 0.3797 - val_accuracy: 0.8750
# Epoch 37/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.3905 - accuracy: 0.8898 - val_loss: 0.3803 - val_accuracy: 0.9062
# Epoch 38/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.3851 - accuracy: 0.8976 - val_loss: 0.4163 - val_accuracy: 0.8125
# Epoch 39/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.3997 - accuracy: 0.8858 - val_loss: 0.4237 - val_accuracy: 0.8125
# Epoch 40/40
# 3/3 [==============================] - 6s 2s/step - loss: 0.3840 - accuracy: 0.8858 - val_loss: 0.3923 - val_accuracy: 0.9062

# %%
#Evaluamos con el nuevo modelo
model_tfLearning.evaluate(x = x_test, y = y_testOneHot)
# Out:
# 1/1 [==============================] - 1s 502ms/step - loss: 0.5066 - accuracy: 0.8065
# [0.5065655708312988, 0.8064516186714172]
